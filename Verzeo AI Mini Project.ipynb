# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Elakiya\Desktop\Python\Datasets\heart.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.drop("fbs" ,axis="columns",inplace=True)

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope  \
# 0     63    1   3       145   233        0      150      0      2.3      0
# 1     37    1   2       130   250        1      187      0      3.5      0
# 2     41    0   1       130   204        0      172      0      1.4      2
# 3     56    1   1       120   236        1      178      0      0.8      2
# 4     57    0   0       120   354        1      163      1      0.6      2
# ..   ...  ...  ..       ...   ...      ...      ...    ...      ...    ...
# 298   57    0   0       140   241        1      123      1      0.2      1
# 299   45    1   3       110   264        1      132      0      1.2      1
# 300   68    1   0       144   193        1      141      0      3.4      1
# 301   57    1   0       130   131        1      115      1      1.2      1
# 302   57    0   1       130   236        0      174      0      0.0      1
#
#      ca  thal  target
# 0     0     1       1
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (303, 13)

# %%
y=df['target']

# %%
X=df.drop(["restecg", "exang", "slope", "ca", "thal", "target"],axis="columns")

# %%
X
# Out:
#      age  sex  cp  trestbps  chol  thalach  oldpeak
# 0     63    1   3       145   233      150      2.3
# 1     37    1   2       130   250      187      3.5
# 2     41    0   1       130   204      172      1.4
# 3     56    1   1       120   236      178      0.8
# 4     57    0   0       120   354      163      0.6
# ..   ...  ...  ..       ...   ...      ...      ...
# 298   57    0   0       140   241      123      0.2
# 299   45    1   3       110   264      132      1.2
# 300   68    1   0       144   193      141      3.4
# 301   57    1   0       130   131      115      1.2
# 302   57    0   1       130   236      174      0.0
#
# [303 rows x 7 columns]

# %%
from keras.utils import to_categorical

# %%
y=to_categorical(y)

# %%
type(y)
# Out:
# numpy.ndarray

# %%
y.shape
# Out:
# (303, 2)

# %% [markdown]
# # # Architechture

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(32,activation="relu",input_shape=(7,)))
model.add(Dense(16,activation="relu"))
model.add(Dense(2,activation="softmax"))

# %% [markdown]
# # # Compile

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %% [markdown]
# # # Fit the model

# %%
model.fit(X,y,epochs=20)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 0s 7ms/step - loss: 4.7731 - accuracy: 0.6007
# Epoch 2/20
# 10/10 [==============================] - 0s 3ms/step - loss: 2.2514 - accuracy: 0.6568
# Epoch 3/20
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7387 - accuracy: 0.6766
# Epoch 4/20
# 10/10 [==============================] - 0s 2ms/step - loss: 1.6417 - accuracy: 0.6667
# Epoch 5/20
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4487 - accuracy: 0.6766
# Epoch 6/20
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4016 - accuracy: 0.6832
# Epoch 7/20
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3431 - accuracy: 0.6964
# Epoch 8/20
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3163 - accuracy: 0.6799
# Epoch 9/20
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2729 - accuracy: 0.6799
# Epoch 10/20
# ...

# %% [markdown]
# # # Predict

# %%
X
# Out:
#      age  sex  cp  trestbps  chol  thalach  oldpeak
# 0     63    1   3       145   233      150      2.3
# 1     37    1   2       130   250      187      3.5
# 2     41    0   1       130   204      172      1.4
# 3     56    1   1       120   236      178      0.8
# 4     57    0   0       120   354      163      0.6
# ..   ...  ...  ..       ...   ...      ...      ...
# 298   57    0   0       140   241      123      0.2
# 299   45    1   3       110   264      132      1.2
# 300   68    1   0       144   193      141      3.4
# 301   57    1   0       130   131      115      1.2
# 302   57    0   1       130   236      174      0.0
#
# [303 rows x 7 columns]

# %%
df=pd.DataFrame({"age":[65], "sex":[1], "cp":[0], "trestbps":[140], "chol":[250], "thalach":[170], "oldpeak":[1.2]})

# %%
df.shape
# Out:
# (1, 7)

# %%
X.shape
# Out:
# (303, 7)

# %%
model.predict(df)
# Out:
# array([[0.07208177, 0.9279182 ]], dtype=float32)
